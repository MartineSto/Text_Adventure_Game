# %% [markdown]
# # The Python Coder Litmus Test
#
#
# A1: Text Adventure Game Development
#
# Data Science: Python - DAT-5301 - BMBAN2
#
#
# Student ID: 10874334

# %% [markdown]
# <strong>LIST OF REFERENCES<strong>
#
# Mundell, E.J. (2003). "Professors Beware: College Kids Lying 70 Percent of Time." _Reuters Health_. Filippo A. Salustri Webpage. Ryerson University.  <http://deed.megan.ryerson.ca/~fil/t/articles/cheaters03.html>.
#
# Kusterer, C. (2019). Python for Business Analytics - A Nontechnical Approach for Nontechnical People.

# %%
"""
DocString:
    
    A) Introduction:
    This game is based on the course Data Science in Python with Professor Kusterer. 
    The target audience is thereby Business Analytics students, people considering 
    Business Analytics, and professors with interest of Business Analytics. 
    The game is inspired by random quotas from Chase Kusterer, while preparing his 
    students for a year with coding.   
    The following is the games four stages:

    Stage 1: Setting up and preparing
    Stage 2: Getting the right habits
    Stage 3: Pad Thai
    Stage 4: Lie stage
    
    B) Known Bugs and/or Errors:
    Possible repeat of questions in Lie stage.
    
"""

#############################################################################
# The following is applicable throughout the code:
# \n is applied to get a new line, othertimes triple " is used with enter
# Input function is declered with prompt, and includes instructions for input
# <Press any key to continue> is used to creat pauses and engage user
# ">" is used to show input area
#
#############################################################################


# Importing random for us in functions
import random


# Introducing the game for player with input function to start the game
input(prompt = """
******************************************************************************

Welcome to the Python coder litmus test!

This game is all about testing your ability to be a successful coder in Python. 
You are a Business Analytics student at HULT and these are the first weeks of 
your Master’s. Your moral, judgment and habits will be tested. Do you think you 
have what it takes to get through endless classes with Professor Kusterer?

******************************************************************************          

<Press enter to continue>
""")


# Stage 1 – Setting up and preparing 
# Defining first stage
def stage_1(): 
 
    # Declaring a question with a prompt to be answered in input
    ram = input(prompt = """
The Master's that you have enrolled to not only requires a lot from you, but also 
your computer. Do you know the minimum required RAM needed for the Business Analytics 
program? 
    1. 8 GB RAM
    2. 12 GB RAM
    3. 16 GB RAM
    4. What is RAM?
    """)

    # Converting object to lowercase using .casefold() to facilitate conditional statement
    ram = ram.casefold()
    
    # Developing a conditional statement
    if ram == "1" or "8" in ram:
        print("\nBe prepared for your computer crashing. Try again. ")
        stage_1() # Sending player back and repreats question

    elif ram == "2"  or "12" in ram:
        print("\nCorrect! You know your stuff. ")
        stage_1_q_2() # Sending player to next question
    
    elif ram == "3" or "16" in ram:
        print("""\nWell, you can at least feel safe with that much. 
The requirement however... Try again, please. """)
        stage_1() # Sending player back and repreats question
    
    elif ram == "4" or "what" in ram:
        print("""
\nSorry, this Master's is not for you. Have you considered marketing? 
    """)
        fail() # Sending player to fail and ask if they want to play again
    
    else:
        print("\nSomething went wrong, please try again. ")
        stage_1() # Sending player back and repreats question
        
    
    
def stage_1_q_2():    
    # Declaring a question with a prompt to be answered in input
    packages = input(prompt = """
To set up your computer for Python you need to install Anaconda and import some 
packages you need to download, to make your Python experience a whole lot better. 
To download these, what is you approach?
    1. Ask a teammate and install during the first class
    2. Using help() inside a shell to figure this out
    3. You are using the guide on canvas and have it ready before first class
    """)
    
    # Converting object to lowercase using .casefold() to facilitate conditional statement
    packages = packages.casefold()
 
    # Developing a conditional statement
    if packages == "1" or "teammate" in packages or "during" in packages:
        print("""
*Error, lost internet connection*

You were not the only one downloading during class and the internet crashes! 
Because of you and others like you everyone must go home. 
 """)
        fail() # Sending player to fail and ask if they want to play again

    elif packages == "2" or "help" in packages or "shell" in packages:
        print("""\nLike your approach, however, not what we are looking for. 
Try again. """)
        input(prompt = "<Press enter to continue>")
        stage_1_q_2() # Sending player back and repreats question

    elif packages == "3" or "guide" in packages or "canvas" in packages:
        print("\nWell done! That's what you are supposed to do.")
        stage_2() # Sending player to next question

    else:
        print("\nSomething went wrong, please try again. ")
        input(prompt = "<Press enter to continue>")
        stage_1_q_2() # Sending player back and repreats question
                
    
    
# Stage 2 - Getting the right habits
def stage_2():
    print("""
You made it through the set up! Now, let’s look at your study routines. 
How would you act in the following scenarios?
""")
    input(prompt = "\n<Press enter to continue>")
    stage_2_q_1()
    
    
    
def stage_2_q_1():    
    # Declaring a question with a prompt to be answered in input
    bugs = input(prompt = """
You have a deadline tomorrow, but you still have some bugs in your code. 
What do you do?
    1. Stay awake until you have killed all the bugs 
    2. Take a break to watch Borat and look at it tomorrow 
    3. Send your code to your programmer uncle
    4. Submit, and hope the professor doesn’t find them 
    """)

    # Converting object to lowercase using .casefold() to facilitate conditional statement
    bugs = bugs.casefold()
    
    # Developing a conditional statement
    if bugs == "1" or "stay" in bugs or "awake" in bugs:
        print("""
That's not the best approach. Often, a break from the coding and some sleep is 
all that is needed to kill those bugs. Try again. 
    """)
        input(prompt = "\n<Press enter to continue>")
        stage_2_q_1() # Sending player back and repreats question

    elif bugs == "2"  or "break" in bugs or "tomorrow" in bugs or "borat" in bugs:
        print("""
Excellent choice! Did you know that Borat has a scene that "shows" how coding works? 
You will find it much easier to look at it tomorrow. """)
        stage_2_q_2() # Sending player to next question
    
    elif bugs == "3" or "send" in bugs or "uncle" in bugs:
        print("""\nShady business, not sure how much you will learn by doing that. 
Try again. """)
        input(prompt = "\n<Press enter to continue>")
        stage_2_q_1() # Sending player back and repreats question
              
    elif bugs == "4" or "professor" in bugs:
        print("\nSorry, but he will. Try again. ")
        input(prompt = "\n<Press enter to continue>")
        stage_2_q_1() # Sending player back and repreats question
         
    else:
        print("\nSomething went wrong, please try again. ")
        input(prompt = "\n<Press enter to continue>")
        stage_2_q_1() # Sending player back and repreats question    
        
        
        
def stage_2_q_2():              
              
    # Declaring a question with a prompt to be answered in input
    food = input(prompt = """
You are under a lot of pressure, with a whole bunch of exams the next days ahead. 
You understand that you need to save time where you can. 
    1. You order pizza
    2. You take the time to prep a meal with a complex combination of macros 
    3. You decide to skip a few meals – to spare both time and calories
    """)           
     
    # Converting object to lowercase using .casefold() to facilitate conditional statement
    food = food.casefold()   
    
    # Developing a nested conditional statement
    if food == "1" or "pizza" in food:
        print("""
Ok, so you are one of those. Too bad as your brain is part of the body too and 
need proper nutrition...
    """)
    
        print("""
You are not going to get far with eating pizza every time you are in these situations. 
Therefore, you get a new chance - do you want to change your answer? """)
     
        answer = input(prompt = "(Yes/No) >")
       
        # Converting object to lowercase using .casefold() to facilitate conditional statement
        answer = answer.casefold()
        
        if answer == "yes" or "y" in answer:
                print("")
                print("\nGreat! Choose wisely this time.")
                input(prompt = "\n<Press enter to continue>")
                stage_2_q_2() # Sends back to question and gives player a new chance to answer 
          
        elif answer == "no" or "n" in answer:
                input(prompt = """
Ok, but good luck. Press any key to continue your coding journey. 
Watch out for a good meal suggestion, and we can still get you on the right path. """)
                stage_3() # Sending player to next question 
    
        else:
            print("""
We didn't understand that, but you will get a chance to rethink your food anyway. """)
            stage_2_q_2() # Sending player back and repreats question        
        
    elif food == "2" or "prep" in food or "meal" in food or "macros" in food:
        print("\nAmazing! You need all the good stuff. ")
        stage_3() # Sending player to next question
    
    elif food == "3" or "skip" in food:
        print("""
That sounds like a poor approach, it is difficult to concentrate while being in 
calorie deficit. Try another approach. """)
        stage_2_q_2() # Sending player back and repreats question
           
    else:
        print("\nSomething went wrong, please try again. ")
        stage_2_q_2() # Sending player back and repreats question
    
        
# Stage 3 - Pad Thai    
def stage_3(): 
    print("""
With good study habits, enough sleep, and good nutrition you are going to do 
great. Talking about healthy food, do you know about Pad Thai? It supposed to be 
something great to eat for coders! \n""")
    input(prompt = "\n<Press enter to continue>")
    stage_3_q_1() # Sends player to question after introducing the stage 
    
    
def stage_3_q_1():
    # Declaring a question with a prompt to be answered in input
    pad_thai = input(prompt = """\nWhat ingredient is not a part of Pad Thai?        
        1. Rice noodles
        2. Beansprouts
        3. Firm tofu 
        4. Cilantro
        5. Chopped peanuts
    """)    
    
    # Converting object to lowercase using .casefold() to facilitate conditional statement
    pad_thai = pad_thai.casefold()
    
    # Developing a new conditional statement
    if pad_thai == "1" or "rice" in pad_thai or "noodles" in pad_thai:
        print("""
Sorry, but have you seen Pad Thai? Rice noodles is the base. Try again. 
    """)
        stage_3_q_1() # Sending player back and repreats question
        
    elif pad_thai == "2" or "Beansprouts" in pad_thai:
        print("\nNope, that's an ingredient. Try again. ")
        stage_3_q_1() # Sending player back and repreats question

    elif pad_thai == "3" or "tofu" in pad_thai:
        print("""
That's a part of proper Pad Thai. Tofu is actually a Chinese ingredient and is 
similar to cheese in some ways - and often an ingredient in Thai food. Try again. 
    """)
        stage_3_q_1() # Sending player back and repreats question

    elif pad_thai == "4" or "cilantro" in pad_thai:
        print("\nCorrect! You know your Pad Thai. ")  
        stage_3_q_2() # Sending player to next question

    elif pad_thai == "5" or "chopped" in pad_thai or "peanuts" in pad_thai:
        print("""
Nice try, but chopped peanuts is a key ingredient for perfect Pad Thai. 
Try again. """)
        stage_3_q_1() # Sending player back and repreats question

    else:
        print("\nSomething went wrong, please try again. ")
        stage_3_q_1() # Sending player back and repreats question

        
        
def stage_3_q_2():
    # Declaring a question with a prompt to be answered in input
    nuts = input(prompt = """
But wait, before we recommend you eat Pad Thai, are you allergic to nuts?
    1. Oh, yes!
    2. Nope
    3. I am not sure
""")       
    
    # Converting object to lowercase using .casefold() to facilitate conditional statement
    nuts = nuts.casefold()
              
    # Developing a new conditional statement
    if nuts == "1" or "yes" in nuts:
        print("""
Your throat is starting to swell, and you can’t see anymore. You died. Luckily, 
your family can blame HULT for the homework and get an easy settlement. 
""")
        input(prompt = "\n<Press enter to be revived and start again>\n")
        stage_1() # Sends player back to start

    elif nuts == "2"  or "no" in nuts:
        print("\nPerfect, then you now know what to eat to be a good coder. ")
        stage_4() # Sending player to next question
    
    elif nuts == "3" or "not" or "sure" in nuts:
        print("\nPlease check that out, and come back when you know. ")
        input(prompt = "\n<Press enter to answer again>")
        stage_3_q_2() # Sending player back and repreats question          
            
    else:
        print("\nSomething went wrong, please try again. ") 
        stage_3_q_2() # Sending player back and repreats question
     
    
# Stage 4 - Lie Room   
def stage_4():
    print("""
You come this far, amazing! You probably heard that business analytics requires 
a lot of hard work. Therefore, we have one final question to make sure you can 
make it through this!""")
    stage_4_q_1() # Sends player forward to question after introducing the last stage   
    
def stage_4_q_1():
    # Declaring study_hours
    study_hours = input(prompt = "\nHow many hours did you study this week? ")   
    
    # Checking for wrong type of input with try/except
    try:
        # Converting the object to int
        study_hours = int(study_hours)
        
    except:
        print("\nNot exactly what we were looking for, please enter a number")
        input(prompt = "\n<Press enter to answer again>")
        stage_4_q_1() # Sending player back and repreats question
    
    # Developing a conditional statement
    if study_hours > 168:
        print("""
Haha, nice try! But there is not that many hours in a week. 
Let's try that again and be honest. """)
        stage_4_q_1() # Sending player back and repreats question
    
    # Creating an easter egg
    elif study_hours == 168:
        print("""
█╗    ██╗ ██████╗ ██╗    ██╗
██║    ██║██╔═══██╗██║    ██║
██║ █╗ ██║██║   ██║██║ █╗ ██║
██║███╗██║██║   ██║██║███╗██║
╚███╔███╔╝╚██████╔╝╚███╔███╔╝
 ╚══╝╚══╝  ╚═════╝  ╚══╝╚══╝ 
You spend every single hour of every single day studying. But wait, 
you must be a robot!?! Guess robots are taking our jobs here as well... """)
        print("\nLet a human answer this next time. ")
        stage_4_q_1() # Sending player back and repreats question
    
    
    elif study_hours > 20:
        print("\nYou will do good, keep up the good work! ")
        lie_stage() # Sending player to the lie questioning

    elif study_hours >= 15:
        print("\nThat's sufficient! ")
        lie_stage() # Sending player to the lie questioning

    elif study_hours < 15:
        print("""
That's not going to get you through this. We promise you, just debugging your 
first code takes more time!
 """)
        fail() # Sending player to fail and ask if they want to play again

    else:
        print("""\nSomething went wrong, please try again. 
Write a whole number in digits without , or . """) 
        stage_4_q_1() # Sending player back and repreats question
     
    
# Defining lie stage 
def lie_stage():  
    
    # Random number of questions interrogation into possible lie    
    lie = random.randint(1,10) 
    lie = int(lie)
    
    if lie > 7:
        print("""
Did you know that 70% of students lie to their teacher? But we choose to trust you. 
We usually interrogate more, but you got lucky. There must be something special 
about you. Now you can relax with some Family Guy! """)
        win() # Sending player to winner message
        
        
    elif lie <= 7:
        print("\nBut wait, are you sure about that?")
        lie_questioning()
        
def lie_questioning(): 
    
    # Developing a list with questions to be randomly selected
    question_list = [ 
"""\nDid you know that 70% of students lie to their teacher, so are you sure you 
studied that much? """,
"""\nMost students lie about their workload to make sure they don't get more, so 
are you sure you studied that much? """,
"""\nPeople lie more in writing, and you wrote this to a computer - are you sure you 
studied that much? """,
"""\nSome people are special and don't need to study that much, but are you 
sure you studied that much? """,
"""\nStudents have weird perception of time while studying. Are you sure you studied 
that much? """, 
"""\nIf you say something out load, you are more likely to do it. If that was your 
goal, it's ok that you lied. Did you study that much? """, ]

    questions = random.randint(2, 4)

    # Creating a while loops
    while questions > 0:
        question = random.choice(question_list)
        print(question)
        print(" ") 
        
        answer = input(prompt = "(Yes/No) > ")
        
        # Converting object to lowercase using .casefold() to facilitate conditional statement
        answer = answer.casefold()

        if answer == "yes" or "y" in answer:
            questions -=1

        elif answer == "no" or "n" in answer:
            print("""
Of course, you did. We mean, based on the statistics, the odds were not with you. 
But even when you lie you should sometimes just stick with it unless you are caught.
Try again and be honest this time.
        """)
            stage_4_q_1() # Sending player back and repreats question

        else:
            print("""\nError, please answer with "yes" or "no". """)
            lie_questioning() # Sending player back and repreats question
        
    win()

# Defining function to play again        
def playagain():
    print("""
Thank you for playing! Do you wish to play again? """)
    
    answer = input(prompt = "\n(Yes or No) >")    
    
    # Converting object to lowercase using .casefold() to facilitate conditional statement
    answer = answer.casefold()
    
    # Developing a conditional statement
    if answer == "yes" or "y" in answer:
        print("\nGreat, let's try again! ")
        input(prompt = "\n<Press enter to continue>\n")
        stage_1() # Sending player back to start and replays game

    elif answer == "no" or "n" in answer:
        input(prompt = "\n<Press enter to exit>\n") # Let player end game
        
    else:
        print("""\nError, please answer with "yes" or "no". """)
        playagain() # Repeating play again question
    
# Defining fail function    
def fail():
    print("""
You've failed and didn’t become a programmer! Go watch some Monty Python. And try again next year.
What have coding ever done for us anyway?
    
Thank you for playing! Do you wish to play again? """)
    
    answer = input(prompt = "\n(Yes or No) >")    
    
    # Converting object to lowercase using .casefold() to facilitate conditional statement
    answer = answer.casefold()
    
    # Developing a conditional statement
    if answer == "yes" or "y" in answer:
        print("\nGreat, let's try again! ")
        input(prompt = "\n<Press enter to continue>\n")
        stage_1() # Sending player back to start and replays game

    elif answer == "no" or "n" in answer:
        input(prompt = "\n<Press enter to exit>\n") # Let player end game
        
    else:
        print("""\nError, please answer with "yes" or "no". """)
        fail() # Repeating question

        
    
#Defining win function
def win():
    print("""
  ____                            _         _       _   _                  
  / ___|___  _ __   __ _ _ __ __ _| |_ _   _| | __ _| |_(_) ___  _ __  ___  
 | |   / _ \| '_ \ / _` | '__/ _` | __| | | | |/ _` | __| |/ _ \| '_ \/ __| 
 | |__| (_) | | | | (_| | | | (_| | |_| |_| | | (_| | |_| | (_) | | | \__ \ 
  \____\___/|_| |_|\__, |_|  \__,_|\__|\__,_|_|\__,_|\__|_|\___/|_| |_|___/ 
                   |___/                                                    

You made it through all the tests! With good study habits, moral and nutrition 
you will make it through this year. But don't forget to code every day! 
Best of luck! """)

    input(prompt = "\n<Press enter to continue>")

    
    print(""" 
******************************************************************************
Disclaimer:
This game was developed while eating pizza and debugged all night. 
The developer has also never seen Monty Python, Family Guy, Ted Lasso or Borat,
and is allergic to peanuts, so Pad Thai was also never an option.
******************************************************************************
    """)
    playagain()
    
    
stage_1()
